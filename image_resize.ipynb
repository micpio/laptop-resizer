# %%
import os
cwd = os.getcwd()
print(cwd)

import glob
from PIL import Image
import os, sys

fi = os.getcwd()+"/processed/"
print(fi)
def ProcessOne(f):
    files = (os.listdir(fi))
    # Create a list of files to process
    files = [f for f in glob.glob("*.jpeg")]
    print("......................................................................")
    new_width = int(input("enter width desired"))
    print("......................................................................")
    for f in files:
            print("lets resize some images")
            print(f'Opening {f}')
            im = Image.open(f)
            if im.size >= (50,50): #process files that meet ext creds
                                     #minimum size to begin 300x300
                aspect_ratio = round((im.height / im.width),2)
                print("......................................................................")
                print("aspect ratio")
                print(aspect_ratio)
                print("......................................................................")
                new_height = round(new_width * aspect_ratio)
                new = im.resize((new_width, new_height))
                rf  =fi+ "re"+f #format for file sent to processed
                if "re" not in f:
                    print("......................................................................")
                    new.save( rf)    #save
                    print(f)
                    print("originnal size")
                    print(im.size ) 
                    print("......................................................................")
                    print("resized with new name" )
                    print(rf)
                    print("new size")
                    print(new.size)
                    print("......................................................................")
                    print("Thank You ")
                    print("......................................................................")                
                else:
                    print("Thank You no more files available")
                    print("......................................................................")
                    
#if __name__ == '__main__':
                


ProcessOne(fi)
# Out:
# /home/micpio/workbench
# /home/micpio/workbench/processed/
# ......................................................................
# enter width desired 200
# ......................................................................
# lets resize some images
# Opening 2.jpeg
# ......................................................................
# aspect ratio
# 1.5
# ......................................................................
# ......................................................................
# 2.jpeg
# originnal size
# (200, 300)
# ......................................................................
# resized with new name
# /home/micpio/workbench/processed/re2.jpeg
# new size
# (200, 300)
# ......................................................................
# Thank You
# ......................................................................
# lets resize some images
# Opening 3.jpeg
# ......................................................................
# aspect ratio
# 1.25
# ......................................................................
# ......................................................................
# 3.jpeg
# originnal size
# (564, 705)
# ......................................................................
# resized with new name
# /home/micpio/workbench/processed/re3.jpeg
# new size
# (200, 250)
# ......................................................................
# Thank You
# ......................................................................
# lets resize some images
# Opening 1.jpeg
# ......................................................................
# aspect ratio
# 1.32
# ......................................................................
# ......................................................................
# 1.jpeg
# originnal size
# (200, 264)
# ......................................................................
# resized with new name
# /home/micpio/workbench/processed/re1.jpeg
# new size
# (200, 264)
# ......................................................................
# Thank You
# ......................................................................
